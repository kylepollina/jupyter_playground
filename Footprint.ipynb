# %%
import pandas

# %%
footprint_data_full = pandas.read_csv('data/GlobalFootPrintNetwork/countries.csv')
footprint_data_full
# Out:
#                        Country                    Region  \
# 0                  Afghanistan  Middle East/Central Asia
# 1                      Albania   Northern/Eastern Europe
# 2                      Algeria                    Africa
# 3                       Angola                    Africa
# 4          Antigua and Barbuda             Latin America
# ..                         ...                       ...
# 183                   Viet Nam              Asia-Pacific
# 184  Wallis and Futuna Islands              Asia-Pacific
# 185                      Yemen  Middle East/Central Asia
# 186                     Zambia                    Africa
# 187                   Zimbabwe                    Africa
#
#      Population (millions)   HDI GDP per Capita  Cropland Footprint  \
# 0                    29.82  0.46        $614.66                0.30
# 1                     3.16  0.73      $4,534.37                0.78
# 2                    38.48  0.73      $5,430.57                0.60
# ...

# %%
us_footprint = footprint_data_full[footprint_data_full.Country == 'United States of America']

# %%
us_footprint
# Out:
#                       Country         Region  Population (millions)   HDI  \
# 179  United States of America  North America                  317.5  0.91
#
#     GDP per Capita  Cropland Footprint  Grazing Footprint  Forest Footprint  \
# 179     $49,725.00                1.13                0.3              0.67
#
#      Carbon Footprint  Fish Footprint  ...  Cropland  Grazing Land  \
# 179               5.9            0.12  ...      1.49          0.28
#
#      Forest Land  Fishing Water  Urban Land  Total Biocapacity  \
# 179         1.57           0.33        0.09               3.76
#
#      Biocapacity Deficit or Reserve  Earths Required  Countries Required  \
# 179                           -4.46             4.75                2.19
#
#      Data Quality
# 179             6
#
# [1 rows x 21 columns]
